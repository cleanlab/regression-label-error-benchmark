# %%
import os
import numpy as np 
import pandas as pd

# %%
# !wget -P ./../../../dataset/ -nc https://cleanlab-public.s3.amazonaws.com/RegressionBenchmark/label_aggregation_random.csv
# Out:
# File './../../../dataset/label_aggregation_random.csv' already there; not retrieving.

# %%
path = "./../../../dataset/label_aggregation_random.csv"
dataset_name = os.path.splitext(os.path.basename(path))[0]
data = pd.read_csv(path, index_col=0)
print("shape of data: ", data.shape)
data.head()
# Out:
# shape of data:  (3112, 203)
#    given_label  true_label  vector1_1  vector1_2  vector1_3  vector1_4  \
# 0            0           0   0.342449   0.087047   0.353954  -0.173610
# 1            2           2   0.168401   0.561746   0.074514  -0.575582
# 2            2           0  -0.218530   0.195872  -0.066998  -0.243992
# 3            0           1   0.339654   0.446115   0.235565  -0.226856
# 4            1           0   0.249283   0.070998   0.518882  -0.187396
#
#    vector1_5  vector1_6  vector1_7  vector1_8  ...  vector2_92  vector2_93  \
# 0  -0.068214   0.023361   0.026467   0.524356  ...    0.165388    0.405659
# 1   0.102819  -0.028392  -0.414004   0.290580  ...    0.411701    0.066502
# 2   0.415523  -0.143825  -0.004178   0.156188  ...    0.242910   -0.049662
# 3   0.067015  -0.474700   0.138353   0.278314  ...    0.383484    0.142645
# 4   0.161669   0.105145   0.138301   0.348414  ...    0.141993    0.036351
#
#    vector2_94  vector2_95  vector2_96  vector2_97  vector2_98  vector2_99  \
# 0    0.253031    0.072608   -0.231072   -0.021761    0.305048    0.264608
# 1    0.164121    0.103418   -0.512343   -0.428574   -0.156280    0.340662
# 2   -0.039108   -0.609256   -0.539768   -0.135668   -0.122837   -0.028440
# 3    0.309896   -0.061357   -0.123153   -0.162776    0.103166   -0.307993
# 4    0.285203   -0.335406   -0.446845    0.154867   -0.193063   -0.213497
#
#    vector2_100  true_error
# 0    -0.010648           0
# 1    -0.876581           0
# 2    -0.374013           1
# 3     0.018228           1
# 4    -0.002717           0
#
# [5 rows x 203 columns]

# %%
training_data = data.drop(['true_label', 'true_error'], axis=1)
training_data.head(2)
# Out:
#    given_label  vector1_1  vector1_2  vector1_3  vector1_4  vector1_5  \
# 0            0   0.342449   0.087047   0.353954  -0.173610  -0.068214
# 1            2   0.168401   0.561746   0.074514  -0.575582   0.102819
#
#    vector1_6  vector1_7  vector1_8  vector1_9  ...  vector2_91  vector2_92  \
# 0   0.023361   0.026467   0.524356  -0.216904  ...   -0.247050    0.165388
# 1  -0.028392  -0.414004   0.290580  -0.269118  ...    0.262209    0.411701
#
#    vector2_93  vector2_94  vector2_95  vector2_96  vector2_97  vector2_98  \
# 0    0.405659    0.253031    0.072608   -0.231072   -0.021761    0.305048
# 1    0.066502    0.164121    0.103418   -0.512343   -0.428574   -0.156280
#
#    vector2_99  vector2_100
# 0    0.264608    -0.010648
# 1    0.340662    -0.876581
#
# [2 rows x 201 columns]

# %%
y = training_data['given_label']
X = training_data.drop(['given_label'], axis=1)

###### Add your training code here ###############
# model = 
# model_fit = model.fit(X,y)
# predictions = model.predict(X)

##### saving the predictions ####################
# savepath = "./../predictions/model_predictions.npy"
# np.save(savepath, np.array(predictions))

# %% [markdown]
# ## Section section is relevant only if using AutoGluon
#
# Uncomment the code in following cells and run to generate output and save to predictions folder.

# %% [markdown]
# ### set up arguments

# %%
from autogluon.tabular import TabularPredictor

data_without_label = training_data.drop(['given_label'], axis=1)
savepath = "./../trained_models/"
if not os.path.isdir(savepath):
    os.mkdir(savepath)

predictorArgs = {
                    "path"             : savepath, 
                    "label"            : 'given_label',
                    "eval_metric"      : 'r2',
                    "problem_type"     : 'regression'
                }

hyperparameters = { 
                    'GBM'   : {}, 
                    'FASTAI': {}, 
                    'RF'    : {'criterion': 'squared_error', 
                                'ag_args': {'name_suffix': 'MSE', 
                                'problem_types': ['regression', 'quantile']}}
                    }

# %% [markdown]
# ### Normal Model fitting

# %%
predictor = TabularPredictor(**predictorArgs)
predictor.fit(training_data, hyperparameters=hyperparameters)
leaderboard = predictor.leaderboard(training_data, silent=True)
leaderboard
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./../trained_models/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "./../trained_models/"
# AutoGluon Version:  0.5.2
# Python Version:     3.9.15
# Operating System:   Darwin
# Train Data Rows:    3112
# Train Data Columns: 200
# Label Column: given_label
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1564.0 MB
# 	Train Data (Original)  Memory Usage: 4.98 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 200 | ['vector1_1', 'vector1_2', 'vector1_3', 'vector1_4', 'vector1_5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 200 | ['vector1_1', 'vector1_2', 'vector1_3', 'vector1_4', 'vector1_5', ...]
# 	0.2s = Fit runtime
# 	200 features in original data used to generate 200 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.98 MB (0.3% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.16066838046272494, Train Rows: 2612, Val Rows: 500
# Fitting 3 L1 models ...
# Fitting model: LightGBM ...
# 	0.041	 = Validation score   (r2)
# 	16.1s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	0.0373	 = Validation score   (r2)
# 	17.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 0: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# 	0.0217	 = Validation score   (r2)
# 	2.68s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.0539	 = Validation score   (r2)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 36.45s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./../trained_models/")
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0      RandomForestMSE    0.720325   0.037322        0.050694       0.024627
# 1  WeightedEnsemble_L2    0.495300   0.053898        0.162584       0.074894
# 2             LightGBM    0.431458   0.040956        0.007312       0.005110
# 3      NeuralNetFastAI    0.061152   0.021653        0.102034       0.044745
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  17.319423                 0.050694                0.024627
# 1  36.123277                 0.002544                0.000412
# 2  16.097746                 0.007312                0.005110
# 3   2.678351                 0.102034                0.044745
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          17.319423            1       True          2
# 1           0.027757            2       True          4
# 2          16.097746            1       True          1
# 3           2.678351            1       True          3

# %% [markdown]
# ### Cross Validation fitting

# %%
predictor_cv = TabularPredictor(**predictorArgs) 
predictor_cv.fit(training_data, presets="best_quality", num_stack_levels= 0, hyperparameters=hyperparameters)
leaderboard_cv = predictor_cv.leaderboard(training_data, silent=True)
leaderboard_cv
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./../trained_models/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ...
# AutoGluon will save models to "./../trained_models/"
# AutoGluon Version:  0.5.2
# Python Version:     3.9.15
# Operating System:   Darwin
# Train Data Rows:    3112
# Train Data Columns: 200
# Label Column: given_label
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    1558.95 MB
# 	Train Data (Original)  Memory Usage: 4.98 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 200 | ['vector1_1', 'vector1_2', 'vector1_3', 'vector1_4', 'vector1_5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 200 | ['vector1_1', 'vector1_2', 'vector1_3', 'vector1_4', 'vector1_5', ...]
# 	0.1s = Fit runtime
# 	200 features in original data used to generate 200 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.98 MB (0.3% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'r2'
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 3 L1 models ...
# Fitting model: LightGBM_BAG_L1 ...
# 	Will use sequential fold fitting strategy because Darwin OS does not yet support parallel folding.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# 	0.0555	 = Validation score   (r2)
# 	69.83s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	0.039	 = Validation score   (r2)
# 	16.19s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy
# No improvement since epoch 2: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 1: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 1: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 1: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 2: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 0: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 1: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# No improvement since epoch 0: early stopping
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# 	0.0349	 = Validation score   (r2)
# 	12.77s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.0685	 = Validation score   (r2)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 99.73s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./../trained_models/")
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# [W ParallelNative.cpp:229] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
#                     model  score_test  score_val  pred_time_test  \
# 0  RandomForestMSE_BAG_L1    0.846182   0.038981        0.064988
# 1     WeightedEnsemble_L2    0.540817   0.068474        1.030694
# 2         LightGBM_BAG_L1    0.468320   0.055499        0.078138
# 3  NeuralNetFastAI_BAG_L1    0.241477   0.034850        0.886111
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.131118  16.191232                 0.064988                0.131118
# 1       0.546768  98.828947                 0.001457                0.000201
# 2       0.026577  69.828505                 0.078138                0.026577
# 3       0.388872  12.768242                 0.886111                0.388872
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          16.191232            1       True          2
# 1           0.040968            2       True          4
# 2          69.828505            1       True          1
# 3          12.768242            1       True          3

# %% [markdown]
# ### predicting and saving arrays

# %%
models = {  'normal'            : list(leaderboard['model']), 
            'crossValidation'   : list(np.append(leaderboard_cv['model'], ['oof']))}

predictors = { 'normal'          : predictor, 
               'crossValidation' : predictor_cv}

# check if path is available, else create it. 
pred_path = "./../predictions/"
if not os.path.isdir(pred_path):
    os.mkdir(pred_path)

for model_type in models.keys():
    if model_type == "normal": 
        for model in models[model_type]:
            savepath = os.path.join(pred_path, model+".npy")
            predictions = predictors[model_type].predict(data_without_label, model=model)
            np.save(savepath, np.array(predictions))
    elif model_type == "crossValidation":
        for model in models[model_type]:
            if model == "oof":
                predictions = predictors[model_type].get_oof_pred()
                savepath = os.path.join(pred_path, model+".npy")
            elif model in models['normal']:
                predictions = predictors[model_type].predict(data_without_label, model=model)
                savepath = os.path.join(pred_path, model+"_CV.npy")
            else: 
                predictions = predictors[model_type].predict(data_without_label, model=model)
                savepath = os.path.join(pred_path, model+".npy")

            np.save(savepath, np.array(predictions))
